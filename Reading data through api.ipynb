# %%
import pandas as pd
import requests

# %%
response=requests.get('https://api.cricapi.com/v1/currentMatches?apikey=caf841d2-bf2f-483b-ad04-c7bc46840500&offset=0')

# %%
df=pd.DataFrame(response.json()['data'])

# %%
df
# Out:
#                                       id  \
# 0   5d4505eb-8d9c-4afa-ab8d-5dd7316ee568
# 1   f547eb1b-6555-462b-bcbd-0c4e6c46555f
# 2   a2d8f1f2-a7c1-4eca-a530-89e5bb322cb9
# 3   a819b2ec-0d38-4a4f-9912-411fff9bee8f
# 4   164390d0-6cdf-47cd-a386-e83d1bd5be34
# 5   06e866a1-3349-47f6-93f1-4467336dba13
# 6   5cbb81c7-6d6d-41a0-b92b-f8d9fc31af67
# 7   1380aef9-13bd-4f7f-99fa-7e9c4ed5d96d
# 8   794bdf0d-8b1b-4c10-9857-88b9c792e354
# 9   22455f04-df0f-4917-8d04-4a7bccfbc348
# 10  4211d6d0-2339-44dc-99de-304b54ca1bd2
# 11  05a8e6cc-41e8-4c17-bcbd-fe1a29509baf
# 12  f58b1628-a5bc-4788-aab4-b8494abb5edc
#
#                                                  name  \
# 0                    Kent vs Nottinghamshire, Group A
# 1                         Durham vs Somerset, Group B
# 2                       Surrey vs Lancashire, Group A
# 3                     Yorkshire vs Hampshire, Group A
# 4            B-Love Kandy vs Jaffna Kings, Eliminator
# ...

# %%
df.shape
# Out:
# (13, 16)

# %%
dff=df.iloc[:,0:10]

# %%
dff
# Out:
#                                       id  \
# 0   5d4505eb-8d9c-4afa-ab8d-5dd7316ee568
# 1   f547eb1b-6555-462b-bcbd-0c4e6c46555f
# 2   a2d8f1f2-a7c1-4eca-a530-89e5bb322cb9
# 3   a819b2ec-0d38-4a4f-9912-411fff9bee8f
# 4   164390d0-6cdf-47cd-a386-e83d1bd5be34
# 5   06e866a1-3349-47f6-93f1-4467336dba13
# 6   5cbb81c7-6d6d-41a0-b92b-f8d9fc31af67
# 7   1380aef9-13bd-4f7f-99fa-7e9c4ed5d96d
# 8   794bdf0d-8b1b-4c10-9857-88b9c792e354
# 9   22455f04-df0f-4917-8d04-4a7bccfbc348
# 10  4211d6d0-2339-44dc-99de-304b54ca1bd2
# 11  05a8e6cc-41e8-4c17-bcbd-fe1a29509baf
# 12  f58b1628-a5bc-4788-aab4-b8494abb5edc
#
#                                                  name  \
# 0                    Kent vs Nottinghamshire, Group A
# 1                         Durham vs Somerset, Group B
# 2                       Surrey vs Lancashire, Group A
# 3                     Yorkshire vs Hampshire, Group A
# 4            B-Love Kandy vs Jaffna Kings, Eliminator
# ...
